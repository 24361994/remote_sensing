# %% [markdown]
# <a href="https://colab.research.google.com/github/24361994/24361994/blob/main/segmentation_hileras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %% [markdown]
# * OPEN CV: libreria de visión artificial y machine learning

# %%
import numpy as np

# %% [markdown]
# * numpy libreria de calculo numero y analisis de datos

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# * libreria que permite crear graficos, diagramas, histogramas y mapas

# %%
from matplotlib import cm
from matplotlib import colors
from matplotlib.colors import hsv_to_rgb
from matplotlib import colors
from matplotlib import ticker
from matplotlib.colors import LinearSegmentedColormap

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
plants = cv2.imread('/content/drive/My Drive/NDVI/04_rgb.jpeg')

# %%
plt.imshow(plants)
plt.show()

# %%
hsv = cv2.cvtColor(plants, cv2.COLOR_RGB2HSV)

# %%
plt.imshow(hsv)
plt.show()

# %%
lower_green = np.array([75,110,80])
upper_green = np.array([100,255,255])

# %% [markdown]
# # Arreglar el umbral de color para la segmentación

# %%
mask = cv2.inRange(hsv, lower_green, upper_green)

# %% [markdown]
# * Para la imagen hsv, analizar y buscar todos los colores que e ajusten a mi umbral establecido y establece en base a eso una mascara
#
# * Para mi imagen original, aplicale la mascara generada y elimina lo que no esta dentro de ella.

# %%
result = cv2.bitwise_and(plants, plants, mask= mask)

# %% [markdown]
# * Muestra de la aplicación de la mascara y transformación de espacio BGR (por defecto) hacia RGB (formato original)

# %%
hsv2 = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)
plt.imshow(hsv2)
plt.show()

# %% [markdown]
# * `Comparación con la imagen original, para evaluar la segmentación`

# %%
hsv3 = cv2.cvtColor(plants, cv2.COLOR_BGR2RGB)
plt.imshow(hsv3)
plt.show()
